# %%
import json

# %%
data =  {
    'name': 'Bob',
    'age': 25,
    'is_employed': False,
    'skills': ['python', 'java'],
    'address': {
        'street': '123 Main St.',
        'city': 'New York',
    }
}

# %%
data_str = json.dumps(data)
data_str
# Out:
# '{"name": "Bob", "age": 25, "is_employed": false, "skills": ["python", "java"], "address": {"street": "123 Main St.", "city": "New York"}}'

# %%
with open("output.json", "w") as f:
    json.dump(data, f , indent=4)

# %%
# json_string = '''
# {
#   "books": [
#    {"title" : "The Magic of Thingking Big","author" : "David J. Schwartz " ,"Published" : 1959 },
#    {"title": "Chankya Neeti","author" : "B. K. Chaturvedi" ,"Published" : 2009 },
#    {"title" : "How to Win Friends and Influence People","author" : "Dale Karnegie" , "Published" : 1999 },
#    ],
#   "status_code":200
#  }
# '''
json_string = '''
{
  "books": [
    {"title" : "The Magic of Thinking Big","author" : "David J. Schwartz " ,"Published" : 1959 },
    {"title": "Chankya Neeti","author" : "B. K. Chaturvedi" ,"Published" : 2009 },
    {"title" : "How to Win Friends and Influence People","author" : "Dale Carnegie" ,"Published" : 1999 }
  ],
  "status_code":200
}
'''

import json
data = json.loads(json_string)
print(data)
# Out:
# {'books': [{'title': 'The Magic of Thinking Big', 'author': 'David J. Schwartz ', 'Published': 1959}, {'title': 'Chankya Neeti', 'author': 'B. K. Chaturvedi', 'Published': 2009}, {'title': 'How to Win Friends and Influence People', 'author': 'Dale Carnegie', 'Published': 1999}], 'status_code': 200}

# %%
books = data['books']
print(books)
# Out:
# [{'title': 'The Magic of Thinking Big', 'author': 'David J. Schwartz ', 'Published': 1959}, {'title': 'Chankya Neeti', 'author': 'B. K. Chaturvedi', 'Published': 2009}, {'title': 'How to Win Friends and Influence People', 'author': 'Dale Carnegie', 'Published': 1999}]

# %%
books_list = [{book['title']:book['author']}for book in books]
books_list
# Out:
# [{'The Magic of Thinking Big': 'David J. Schwartz '},
#  {'Chankya Neeti': 'B. K. Chaturvedi'},
#  {'How to Win Friends and Influence People': 'Dale Carnegie'}]
