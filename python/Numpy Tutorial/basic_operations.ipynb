# %%
import numpy as np

# %%
rev_q1 = np.array([10,12,9])
rev_q1.ndim
# Out:
# 1

# %%
rev = np.array([[10,12,9],[12,15,7]])
rev.ndim
# Out:
# 2

# %%
rev
# Out:
# array([[10, 12,  9],
#        [12, 15,  7]])

# %%
rev.size
# Out:
# 6

# %%
rev.shape
# Out:
# (2, 3)

# %%
np.sort(rev)
# Out:
# array([[ 9, 10, 12],
#        [ 7, 12, 15]])

# %%
rev.flatten()
# Out:
# array([10, 12,  9, 12, 15,  7])

# %%
rev.min()
# Out:
# np.int64(7)

# %%
rev.max()
# Out:
# np.int64(15)
