# %%
a1 = 'bread'
a2 = 'butter'
a3 = 'cheese'
a4 = 'jam'

# %%
a = ['bread','butter','cheese','jam']
a
# Out:
# ['bread', 'butter', 'cheese', 'jam']

# %%
a[0]
a[1]
# Out:
# 'butter'

# %%
a[2]
# Out:
# 'cheese'

# %%
a[0]
# Out:
# 'bread'

# %%
a[:2]
# Out:
# ['bread', 'butter']

# %%
a[2:]
# Out:
# ['cheese', 'jam']

# %%
a.append('chowmein')

# %%
a
# Out:
# ['bread', 'butter', 'cheese', 'jam', 'chowmein']

# %%
a.remove('chowmein')
a
# Out:
# ['bread', 'butter', 'cheese', 'jam']

# %%
a =  ['bread', 'butter', 'cheese', 'jam']
a
# Out:
# ['bread', 'butter', 'cheese', 'jam']

# %%
a.remove('chowmein')
a
# Out:
# ['bread', 'butter', 'cheese', 'jam']

# %%
a[2:]
# Out:
# ['cheese', 'jam']

# %%
a[2:] = ['almonds']
a
# Out:
# ['bread', 'butter', 'almonds']

# %%
'rice' in a
# Out:
# False

# %%
'almonds' in a
# Out:
# True

# %%
expenses = [ 15,12,19,5]
expenses.sort(reverse = 'true')
expenses
# Out:
# [19, 15, 12, 5]
