# %%
myset = set([1,2,3,4,5])
myset
# Out:
# {1, 2, 3, 4, 5}

# %%
myset = {5,6,7,8}

# %%
myset
# Out:
# {5, 6, 7, 8}

# %%
menu = {"Dosa","Idli","Briyani"}
menu
# Out:
# {'Briyani', 'Dosa', 'Idli'}

# %%
menu.add("Pizza")
menu
# Out:
# {'Briyani', 'Dosa', 'Idli', 'Pizza'}

# %%
'Dosa' in menu
# Out:
# True

# %%
"Burger" in menu
# Out:
# False

# %%
a = {'Rahul','Mohan','Rohan'}
b = {'Kabir','Pankaj','Ankit'}
a | b
# Out:
# {'Ankit', 'Kabir', 'Mohan', 'Pankaj', 'Rahul', 'Rohan'}

# %%
a - b
# Out:
# {'Mohan', 'Rahul', 'Rohan'}
