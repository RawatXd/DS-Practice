# %%
import pandas as pd

df = pd.read_csv("home_prices.csv")
df.sample(5)
# Out:
#     area_sqr_ft  price_lakhs  bedrooms
# 6          1085        116.0         3
# 5          1325         80.1         2
# 7          1110         45.0         2
# 11          700         49.0         2
# 9           960         89.0         2
